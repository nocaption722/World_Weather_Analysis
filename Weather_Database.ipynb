# %%
import numpy as np 
from citipy import citipy
import gmaps
import requests
import pandas as pd 
from datetime import datetime

from config import weather_api_key
from config import g_key

# %%
# Generate 1,500 random latitudes and longitudes, and zip them as a list of tuples
lats = np.random.uniform(-90.0,90.0, size=2000)
lngs = np.random.uniform(-180.0,180.0,size=2000)
lats_lngs = zip(lats, lngs)
coordinates = list(lats_lngs)

# Get the nearest city using the citipy module.
cities = list()
for coord in coordinates:
    cities_name = citipy.nearest_city(coord[0],coord[1]).city_name
    if cities_name not in cities:
        cities.append(cities_name)
print(cities[:10], 'Generate', len(cities))
# Out:
# ['tabiauea', 'rikitea', 'celestun', 'ushuaia', 'butaritari', 'bethel', 'thompson', 'tahta', 'tibiri', 'port hardy'] Generate 760

# %%
# Perform an API call with the OpenWeatherMap.

# initial counters for log and sets
record_count = 1 
set_count = 1

city_data = list()
basic_url = "http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=" + weather_api_key

print('Beginning Data Retrieval     ')
print("-----------------------------")
# use enumerate() method to loop index and item simutanously 
for i, item in enumerate(cities):
    if i % 50 == 0 and i != 0 :
        record_count = 1  
        set_count +=1 
    # build URL for API call
    url = basic_url + '&q=' + item
    # Log the URL, record, and set numbers and the city.
    print(f'Processing Record {record_count} of Set {set_count} | {item}')
    # increment record count
    record_count +=1

    try:
        js = requests.get(url).json()
        city_name = item
        city_country = js['sys']['country']
        city_UTCdate = js['dt']
        city_date = datetime.utcfromtimestamp(city_UTCdate).strftime('%Y-%m-%d %H:%M:%S')
        city_lat = js['coord']['lat']
        city_lon = js['coord']['lon']
        city_max_temp = js['main']['temp_max']
        city_humidity = js['main']['humidity']
        city_cload = js['clouds']['all']
        city_wind_speed = js['wind']['speed']
        city_weather_description = js['weather'][0]['description']

        # raining info
        try:
            js['weather'][0]['main'] == 'Rain'
            city_rain = js['rain']['3h']
        except:
            city_rain = 0.000

        # snowing info
        try:
            js['weather'][0]['main'] == 'Snow'
            city_snow = js['snow']['3h']
        except:
            city_snow = 0    

        # append as a list of dictionaries
        city_data.append({'City':city_name, 'Country':city_country, 'Date':city_date, 
                        'Lat':city_lat, 'Lng': city_lon,'Max Temp':city_max_temp,
                        'Humidity':city_humidity,'Cloudiness': city_cload,'Wind Speed':city_wind_speed,
                        'Current Description':city_weather_description,
                        'Rain inches (last 3 hrs)':city_rain,'Snow inches (last 3 hrs)':city_snow})
    except:
        print("City not found. Skipping...")
        pass
print('-------------------------------')
print('Data Retrieval Complete        ')
print('-------------------------------')

print(len(city_data))
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | tabiauea
# City not found. Skipping...
# Processing Record 2 of Set 1 | rikitea
# Processing Record 3 of Set 1 | celestun
# Processing Record 4 of Set 1 | ushuaia
# Processing Record 5 of Set 1 | butaritari
# Processing Record 6 of Set 1 | bethel
# Processing Record 7 of Set 1 | thompson
# Processing Record 8 of Set 1 | tahta
# Processing Record 9 of Set 1 | tibiri
# Processing Record 10 of Set 1 | port hardy
# Processing Record 11 of Set 1 | puerto ayora
# Processing Record 12 of Set 1 | zheshart
# Processing Record 13 of Set 1 | moses lake
# Processing Record 14 of Set 1 | geraldton
# Processing Record 15 of Set 1 | qaanaaq
# Processing Record 16 of Set 1 | westport
# Processing Record 17 of Set 1 | albany
# Processing Record 18 of Set 1 | presidencia roque saenz pena
# Processing Record 19 of Set 1 | castro
# Processing Record 20 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 21 of Set 1 | saint george
# Processing Record 22 of Set 1 | borkenes
# Processing Record 23 of Set 1 | ribeira grande
# Processing Record 24 of Set 1 | hobart
# Processing Record 25 of Set 1 | saldanha
# Processing Record 26 of Set 1 | bambanglipuro
# Processing Record 27 of Set 1 | tuktoyaktuk
# Processing Record 28 of Set 1 | egvekinot
# Processing Record 29 of Set 1 | plettenberg bay
# Processing Record 30 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 31 of Set 1 | jamestown
# Processing Record 32 of Set 1 | vaini
# Processing Record 33 of Set 1 | rawson
# Processing Record 34 of Set 1 | xai-xai
# Processing Record 35 of Set 1 | charlestown
# Processing Record 36 of Set 1 | bluff
# Processing Record 37 of Set 1 | esperance
# Processing Record 38 of Set 1 | provideniya
# Processing Record 39 of Set 1 | palana
# Processing Record 40 of Set 1 | sao filipe
# Processing Record 41 of Set 1 | hermanus
# Processing Record 42 of Set 1 | chokurdakh
# Processing Record 43 of Set 1 | kiama
# Processing Record 44 of Set 1 | port blair
# Processing Record 45 of Set 1 | rantepao
# Processing Record 46 of Set 1 | chuy
# Processing Record 47 of Set 1 | ugoofaaru
# Processing Record 48 of Set 1 | saskylakh
# Processing Record 49 of Set 1 | fasa
# Processing Record 50 of Set 1 | kawalu
# Processing Record 1 of Set 2 | dikson
# Processing Record 2 of Set 2 | panzhihua
# Processing Record 3 of Set 2 | anajatuba
# Processing Record 4 of Set 2 | tateyama
# Processing Record 5 of Set 2 | tunxi
# City not found. Skipping...
# Processing Record 6 of Set 2 | lysa hora
# Processing Record 7 of Set 2 | punta arenas
# Processing Record 8 of Set 2 | oktyabrskiy
# Processing Record 9 of Set 2 | bure
# Processing Record 10 of Set 2 | bambous virieux
# Processing Record 11 of Set 2 | dingle
# Processing Record 12 of Set 2 | mar del plata
# Processing Record 13 of Set 2 | cape town
# Processing Record 14 of Set 2 | ulverstone
# Processing Record 15 of Set 2 | mocuba
# Processing Record 16 of Set 2 | kapaa
# Processing Record 17 of Set 2 | ahipara
# Processing Record 18 of Set 2 | mataura
# Processing Record 19 of Set 2 | warqla
# City not found. Skipping...
# Processing Record 20 of Set 2 | nizhniy chir
# Processing Record 21 of Set 2 | busselton
# Processing Record 22 of Set 2 | yinchuan
# Processing Record 23 of Set 2 | coihaique
# Processing Record 24 of Set 2 | havoysund
# Processing Record 25 of Set 2 | breznice
# Processing Record 26 of Set 2 | xichang
# Processing Record 27 of Set 2 | albury
# Processing Record 28 of Set 2 | bengkulu
# Processing Record 29 of Set 2 | arraial do cabo
# Processing Record 30 of Set 2 | lebu
# Processing Record 31 of Set 2 | urdzhar
# City not found. Skipping...
# Processing Record 32 of Set 2 | labuan
# Processing Record 33 of Set 2 | saint-augustin
# Processing Record 34 of Set 2 | vostok
# Processing Record 35 of Set 2 | bredasdorp
# Processing Record 36 of Set 2 | udgir
# Processing Record 37 of Set 2 | atuona
# Processing Record 38 of Set 2 | bud
# Processing Record 39 of Set 2 | golden
# Processing Record 40 of Set 2 | vardo
# Processing Record 41 of Set 2 | juneau
# Processing Record 42 of Set 2 | pevek
# Processing Record 43 of Set 2 | roma
# Processing Record 44 of Set 2 | fortuna
# Processing Record 45 of Set 2 | acarau
# Processing Record 46 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 47 of Set 2 | mezen
# Processing Record 48 of Set 2 | port alfred
# Processing Record 49 of Set 2 | douglas
# Processing Record 50 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 1 of Set 3 | saint-philippe
# Processing Record 2 of Set 3 | pisco
# Processing Record 3 of Set 3 | morehead
# Processing Record 4 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 5 of Set 3 | ponta do sol
# Processing Record 6 of Set 3 | stephenville
# Processing Record 7 of Set 3 | sao joao da barra
# Processing Record 8 of Set 3 | kindersley
# Processing Record 9 of Set 3 | talnakh
# Processing Record 10 of Set 3 | north bend
# Processing Record 11 of Set 3 | susanville
# Processing Record 12 of Set 3 | tadine
# Processing Record 13 of Set 3 | barrow
# Processing Record 14 of Set 3 | hambantota
# Processing Record 15 of Set 3 | carnarvon
# Processing Record 16 of Set 3 | walvis bay
# Processing Record 17 of Set 3 | yumen
# Processing Record 18 of Set 3 | soyo
# Processing Record 19 of Set 3 | altay
# Processing Record 20 of Set 3 | maeriste
# Processing Record 21 of Set 3 | robertsport
# Processing Record 22 of Set 3 | port keats
# Processing Record 23 of Set 3 | motril
# Processing Record 24 of Set 3 | san andres
# Processing Record 25 of Set 3 | roald
# Processing Record 26 of Set 3 | christchurch
# Processing Record 27 of Set 3 | san patricio
# Processing Record 28 of Set 3 | pacific grove
# Processing Record 29 of Set 3 | karimganj
# Processing Record 30 of Set 3 | coahuayana
# Processing Record 31 of Set 3 | otane
# Processing Record 32 of Set 3 | constitucion
# Processing Record 33 of Set 3 | mahad
# Processing Record 34 of Set 3 | mahebourg
# Processing Record 35 of Set 3 | conceicao do mato dentro
# Processing Record 36 of Set 3 | simbahan
# Processing Record 37 of Set 3 | pekalongan
# Processing Record 38 of Set 3 | petropavlovsk-kamchatskiy
# Processing Record 39 of Set 3 | comodoro rivadavia
# Processing Record 40 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 41 of Set 3 | sitio novo do tocantins
# Processing Record 42 of Set 3 | sao jose da coroa grande
# Processing Record 43 of Set 3 | hithadhoo
# Processing Record 44 of Set 3 | north las vegas
# Processing Record 45 of Set 3 | vao
# Processing Record 46 of Set 3 | meulaboh
# Processing Record 47 of Set 3 | laguna
# Processing Record 48 of Set 3 | beloha
# Processing Record 49 of Set 3 | hoshiarpur
# Processing Record 50 of Set 3 | kaitangata
# Processing Record 1 of Set 4 | new norfolk
# Processing Record 2 of Set 4 | kodiak
# Processing Record 3 of Set 4 | kaeo
# Processing Record 4 of Set 4 | kysyl-syr
# Processing Record 5 of Set 4 | avarua
# Processing Record 6 of Set 4 | ayios matthaios
# City not found. Skipping...
# Processing Record 7 of Set 4 | sitka
# Processing Record 8 of Set 4 | amudat
# Processing Record 9 of Set 4 | ridgetown
# Processing Record 10 of Set 4 | hualmay
# Processing Record 11 of Set 4 | souillac
# Processing Record 12 of Set 4 | adrar
# Processing Record 13 of Set 4 | korla
# Processing Record 14 of Set 4 | hovd
# Processing Record 15 of Set 4 | camopi
# Processing Record 16 of Set 4 | georgetown
# Processing Record 17 of Set 4 | sawtell
# Processing Record 18 of Set 4 | cape coast
# Processing Record 19 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 20 of Set 4 | tshane
# Processing Record 21 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 22 of Set 4 | kutum
# Processing Record 23 of Set 4 | hamilton
# Processing Record 24 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 25 of Set 4 | ust-omchug
# Processing Record 26 of Set 4 | naushki
# Processing Record 27 of Set 4 | kalengwa
# Processing Record 28 of Set 4 | najran
# Processing Record 29 of Set 4 | nanortalik
# Processing Record 30 of Set 4 | waitati
# Processing Record 31 of Set 4 | sume
# Processing Record 32 of Set 4 | vrangel
# Processing Record 33 of Set 4 | kahului
# Processing Record 34 of Set 4 | sawakin
# Processing Record 35 of Set 4 | voineasa
# Processing Record 36 of Set 4 | palimbang
# Processing Record 37 of Set 4 | tasiilaq
# Processing Record 38 of Set 4 | namibe
# Processing Record 39 of Set 4 | hilo
# Processing Record 40 of Set 4 | nikolskoye
# Processing Record 41 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 42 of Set 4 | matadi
# Processing Record 43 of Set 4 | umm kaddadah
# Processing Record 44 of Set 4 | mandalgovi
# Processing Record 45 of Set 4 | vilhena
# Processing Record 46 of Set 4 | hofn
# Processing Record 47 of Set 4 | tazovskiy
# Processing Record 48 of Set 4 | chancay
# Processing Record 49 of Set 4 | marawi
# Processing Record 50 of Set 4 | ksenyevka
# City not found. Skipping...
# Processing Record 1 of Set 5 | jiuquan
# Processing Record 2 of Set 5 | berdigestyakh
# Processing Record 3 of Set 5 | faanui
# Processing Record 4 of Set 5 | mogadishu
# Processing Record 5 of Set 5 | longyearbyen
# Processing Record 6 of Set 5 | ponta delgada
# Processing Record 7 of Set 5 | broome
# Processing Record 8 of Set 5 | bani
# Processing Record 9 of Set 5 | funtua
# Processing Record 10 of Set 5 | luderitz
# Processing Record 11 of Set 5 | tari
# Processing Record 12 of Set 5 | shieli
# Processing Record 13 of Set 5 | ancud
# Processing Record 14 of Set 5 | doctor juan manuel frutos
# Processing Record 15 of Set 5 | arlit
# Processing Record 16 of Set 5 | east london
# Processing Record 17 of Set 5 | aquiraz
# Processing Record 18 of Set 5 | cairns
# Processing Record 19 of Set 5 | faya
# Processing Record 20 of Set 5 | san marcos
# Processing Record 21 of Set 5 | ijaki
# City not found. Skipping...
# Processing Record 22 of Set 5 | yellowknife
# Processing Record 23 of Set 5 | plouzane
# Processing Record 24 of Set 5 | katsuura
# Processing Record 25 of Set 5 | touros
# Processing Record 26 of Set 5 | portree
# Processing Record 27 of Set 5 | karratha
# Processing Record 28 of Set 5 | bloemfontein
# Processing Record 29 of Set 5 | guicheng
# City not found. Skipping...
# Processing Record 30 of Set 5 | pivijay
# Processing Record 31 of Set 5 | anchorage
# Processing Record 32 of Set 5 | lorengau
# Processing Record 33 of Set 5 | kruisfontein
# Processing Record 34 of Set 5 | koungheul
# Processing Record 35 of Set 5 | mount isa
# Processing Record 36 of Set 5 | puerto escondido
# Processing Record 37 of Set 5 | bonavista
# Processing Record 38 of Set 5 | florianopolis
# Processing Record 39 of Set 5 | aklavik
# Processing Record 40 of Set 5 | azimur
# City not found. Skipping...
# Processing Record 41 of Set 5 | haines junction
# Processing Record 42 of Set 5 | iqaluit
# Processing Record 43 of Set 5 | leningradskiy
# Processing Record 44 of Set 5 | arinos
# Processing Record 45 of Set 5 | airai
# Processing Record 46 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 47 of Set 5 | san cristobal
# Processing Record 48 of Set 5 | upernavik
# Processing Record 49 of Set 5 | norman wells
# Processing Record 50 of Set 5 | buqayq
# City not found. Skipping...
# Processing Record 1 of Set 6 | kismayo
# Processing Record 2 of Set 6 | the valley
# Processing Record 3 of Set 6 | ratnagiri
# Processing Record 4 of Set 6 | cururupu
# Processing Record 5 of Set 6 | salalah
# Processing Record 6 of Set 6 | keroka
# Processing Record 7 of Set 6 | san quintin
# Processing Record 8 of Set 6 | lolua
# City not found. Skipping...
# Processing Record 9 of Set 6 | toliary
# City not found. Skipping...
# Processing Record 10 of Set 6 | moranbah
# Processing Record 11 of Set 6 | jinchang
# Processing Record 12 of Set 6 | skelleftea
# Processing Record 13 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 14 of Set 6 | jeremie
# Processing Record 15 of Set 6 | qingquan
# Processing Record 16 of Set 6 | temaraia
# City not found. Skipping...
# Processing Record 17 of Set 6 | cabo san lucas
# Processing Record 18 of Set 6 | necochea
# Processing Record 19 of Set 6 | omboue
# Processing Record 20 of Set 6 | redmond
# Processing Record 21 of Set 6 | vallenar
# Processing Record 22 of Set 6 | whitehorse
# Processing Record 23 of Set 6 | biak
# Processing Record 24 of Set 6 | tasbuget
# City not found. Skipping...
# Processing Record 25 of Set 6 | gigmoto
# Processing Record 26 of Set 6 | victoria
# Processing Record 27 of Set 6 | chongwe
# Processing Record 28 of Set 6 | kyzyl-suu
# Processing Record 29 of Set 6 | port-gentil
# Processing Record 30 of Set 6 | hosakote
# Processing Record 31 of Set 6 | tura
# Processing Record 32 of Set 6 | nyrob
# Processing Record 33 of Set 6 | mkushi
# Processing Record 34 of Set 6 | highland springs
# Processing Record 35 of Set 6 | xiongyue
# Processing Record 36 of Set 6 | honiara
# Processing Record 37 of Set 6 | imbituba
# Processing Record 38 of Set 6 | zhangjiakou
# Processing Record 39 of Set 6 | nichinan
# Processing Record 40 of Set 6 | hasaki
# Processing Record 41 of Set 6 | naze
# Processing Record 42 of Set 6 | jilib
# Processing Record 43 of Set 6 | boyolangu
# Processing Record 44 of Set 6 | conde
# Processing Record 45 of Set 6 | matamoros
# Processing Record 46 of Set 6 | puerto carreno
# Processing Record 47 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 48 of Set 6 | wanning
# Processing Record 49 of Set 6 | dien bien
# City not found. Skipping...
# Processing Record 50 of Set 6 | codajas
# Processing Record 1 of Set 7 | broken hill
# Processing Record 2 of Set 7 | atar
# Processing Record 3 of Set 7 | bagotville
# Processing Record 4 of Set 7 | miri
# Processing Record 5 of Set 7 | ann arbor
# Processing Record 6 of Set 7 | mnogovershinnyy
# Processing Record 7 of Set 7 | namatanai
# Processing Record 8 of Set 7 | crepy-en-valois
# Processing Record 9 of Set 7 | joliette
# Processing Record 10 of Set 7 | hirara
# Processing Record 11 of Set 7 | lashio
# Processing Record 12 of Set 7 | kenai
# Processing Record 13 of Set 7 | tiksi
# Processing Record 14 of Set 7 | chapais
# Processing Record 15 of Set 7 | avera
# Processing Record 16 of Set 7 | san angelo
# Processing Record 17 of Set 7 | leshukonskoye
# Processing Record 18 of Set 7 | arcola
# Processing Record 19 of Set 7 | praia da vitoria
# Processing Record 20 of Set 7 | chake chake
# Processing Record 21 of Set 7 | severo-kurilsk
# Processing Record 22 of Set 7 | parvatipuram
# Processing Record 23 of Set 7 | mirnyy
# Processing Record 24 of Set 7 | torbay
# Processing Record 25 of Set 7 | norilsk
# Processing Record 26 of Set 7 | zakupy
# Processing Record 27 of Set 7 | cuajinicuilapa
# Processing Record 28 of Set 7 | tinskoy
# Processing Record 29 of Set 7 | ust-ishim
# Processing Record 30 of Set 7 | cabedelo
# Processing Record 31 of Set 7 | chekhov
# Processing Record 32 of Set 7 | uige
# Processing Record 33 of Set 7 | itoman
# Processing Record 34 of Set 7 | eureka
# Processing Record 35 of Set 7 | attawapiskat
# City not found. Skipping...
# Processing Record 36 of Set 7 | seddon
# Processing Record 37 of Set 7 | ostrovnoy
# Processing Record 38 of Set 7 | bandarbeyla
# Processing Record 39 of Set 7 | dunedin
# Processing Record 40 of Set 7 | rawannawi
# City not found. Skipping...
# Processing Record 41 of Set 7 | nara
# Processing Record 42 of Set 7 | guerrero negro
# Processing Record 43 of Set 7 | akyab
# Processing Record 44 of Set 7 | bitkine
# Processing Record 45 of Set 7 | neyshabur
# Processing Record 46 of Set 7 | barentsburg
# City not found. Skipping...
# Processing Record 47 of Set 7 | asayita
# City not found. Skipping...
# Processing Record 48 of Set 7 | nagato
# Processing Record 49 of Set 7 | placido de castro
# Processing Record 50 of Set 7 | pecos
# Processing Record 1 of Set 8 | vanimo
# Processing Record 2 of Set 8 | skjervoy
# Processing Record 3 of Set 8 | bichena
# Processing Record 4 of Set 8 | abashiri
# Processing Record 5 of Set 8 | campbell river
# Processing Record 6 of Set 8 | isangel
# Processing Record 7 of Set 8 | semporna
# Processing Record 8 of Set 8 | alofi
# Processing Record 9 of Set 8 | penalva
# Processing Record 10 of Set 8 | sambava
# Processing Record 11 of Set 8 | sfantu gheorghe
# Processing Record 12 of Set 8 | henties bay
# Processing Record 13 of Set 8 | tawkar
# City not found. Skipping...
# Processing Record 14 of Set 8 | maxixe
# Processing Record 15 of Set 8 | pali
# Processing Record 16 of Set 8 | jardim
# Processing Record 17 of Set 8 | brae
# Processing Record 18 of Set 8 | sola
# Processing Record 19 of Set 8 | qostanay
# Processing Record 20 of Set 8 | usta muhammad
# Processing Record 21 of Set 8 | stuttgart
# Processing Record 22 of Set 8 | namyslow
# Processing Record 23 of Set 8 | fort nelson
# Processing Record 24 of Set 8 | saleaula
# City not found. Skipping...
# Processing Record 25 of Set 8 | buin
# Processing Record 26 of Set 8 | mackenzie
# Processing Record 27 of Set 8 | ulladulla
# Processing Record 28 of Set 8 | paita
# Processing Record 29 of Set 8 | sao miguel do araguaia
# Processing Record 30 of Set 8 | deputatskiy
# Processing Record 31 of Set 8 | belyy yar
# Processing Record 32 of Set 8 | bairiki
# Processing Record 33 of Set 8 | velizh
# Processing Record 34 of Set 8 | opuwo
# Processing Record 35 of Set 8 | porto velho
# Processing Record 36 of Set 8 | blankenberge
# Processing Record 37 of Set 8 | road town
# Processing Record 38 of Set 8 | sumbawa
# City not found. Skipping...
# Processing Record 39 of Set 8 | totness
# Processing Record 40 of Set 8 | saundatti yellamma
# City not found. Skipping...
# Processing Record 41 of Set 8 | mach
# Processing Record 42 of Set 8 | puerto gaitan
# Processing Record 43 of Set 8 | am timan
# Processing Record 44 of Set 8 | portland
# Processing Record 45 of Set 8 | noyabrsk
# Processing Record 46 of Set 8 | cotonou
# Processing Record 47 of Set 8 | anadyr
# Processing Record 48 of Set 8 | kamyshlov
# Processing Record 49 of Set 8 | ilulissat
# Processing Record 50 of Set 8 | satitoa
# City not found. Skipping...
# Processing Record 1 of Set 9 | weiser
# Processing Record 2 of Set 9 | bay roberts
# Processing Record 3 of Set 9 | manokwari
# Processing Record 4 of Set 9 | yerbogachen
# Processing Record 5 of Set 9 | middle island
# Processing Record 6 of Set 9 | el alto
# Processing Record 7 of Set 9 | paamiut
# Processing Record 8 of Set 9 | husavik
# Processing Record 9 of Set 9 | homer
# Processing Record 10 of Set 9 | khorixas
# Processing Record 11 of Set 9 | grindavik
# Processing Record 12 of Set 9 | bolungarvik
# City not found. Skipping...
# Processing Record 13 of Set 9 | petukhovo
# Processing Record 14 of Set 9 | saint-pierre
# Processing Record 15 of Set 9 | mbuguni
# Processing Record 16 of Set 9 | vestmannaeyjar
# Processing Record 17 of Set 9 | marcona
# City not found. Skipping...
# Processing Record 18 of Set 9 | tall kayf
# Processing Record 19 of Set 9 | oil city
# Processing Record 20 of Set 9 | yuanping
# Processing Record 21 of Set 9 | margate
# Processing Record 22 of Set 9 | nipawin
# Processing Record 23 of Set 9 | asau
# Processing Record 24 of Set 9 | arteaga
# Processing Record 25 of Set 9 | aksarka
# Processing Record 26 of Set 9 | chebarkul
# Processing Record 27 of Set 9 | thunder bay
# Processing Record 28 of Set 9 | pangnirtung
# Processing Record 29 of Set 9 | samarinda
# Processing Record 30 of Set 9 | khatanga
# Processing Record 31 of Set 9 | lasa
# Processing Record 32 of Set 9 | fare
# Processing Record 33 of Set 9 | port lincoln
# Processing Record 34 of Set 9 | port elizabeth
# Processing Record 35 of Set 9 | luanda
# Processing Record 36 of Set 9 | fethiye
# Processing Record 37 of Set 9 | lavrentiya
# Processing Record 38 of Set 9 | komsomolskiy
# Processing Record 39 of Set 9 | takoradi
# Processing Record 40 of Set 9 | springfield
# Processing Record 41 of Set 9 | merauke
# Processing Record 42 of Set 9 | immenstadt
# Processing Record 43 of Set 9 | manzil salim
# Processing Record 44 of Set 9 | solton
# Processing Record 45 of Set 9 | kapit
# Processing Record 46 of Set 9 | dhuwaran
# Processing Record 47 of Set 9 | sanmenxia
# Processing Record 48 of Set 9 | gerash
# Processing Record 49 of Set 9 | marsh harbour
# Processing Record 50 of Set 9 | imeni poliny osipenko
# Processing Record 1 of Set 10 | pristen
# Processing Record 2 of Set 10 | kuching
# Processing Record 3 of Set 10 | taoudenni
# Processing Record 4 of Set 10 | nemuro
# Processing Record 5 of Set 10 | aykhal
# Processing Record 6 of Set 10 | maua
# Processing Record 7 of Set 10 | mahdasht
# Processing Record 8 of Set 10 | machico
# Processing Record 9 of Set 10 | dabakala
# Processing Record 10 of Set 10 | harper
# Processing Record 11 of Set 10 | nhamunda
# Processing Record 12 of Set 10 | matara
# Processing Record 13 of Set 10 | khorol
# Processing Record 14 of Set 10 | weligama
# Processing Record 15 of Set 10 | vila franca do campo
# Processing Record 16 of Set 10 | kuryk
# Processing Record 17 of Set 10 | kavieng
# Processing Record 18 of Set 10 | kolda
# Processing Record 19 of Set 10 | shingu
# Processing Record 20 of Set 10 | cockburn town
# Processing Record 21 of Set 10 | lata
# Processing Record 22 of Set 10 | clyde river
# Processing Record 23 of Set 10 | warrington
# Processing Record 24 of Set 10 | baykit
# Processing Record 25 of Set 10 | northam
# Processing Record 26 of Set 10 | rabo de peixe
# Processing Record 27 of Set 10 | qala
# Processing Record 28 of Set 10 | tidore
# City not found. Skipping...
# Processing Record 29 of Set 10 | vera cruz
# Processing Record 30 of Set 10 | kashi
# Processing Record 31 of Set 10 | klaksvik
# Processing Record 32 of Set 10 | tuatapere
# Processing Record 33 of Set 10 | lumeje
# Processing Record 34 of Set 10 | gaoual
# Processing Record 35 of Set 10 | ixtapa
# Processing Record 36 of Set 10 | fulacunda
# City not found. Skipping...
# Processing Record 37 of Set 10 | kununurra
# Processing Record 38 of Set 10 | hihifo
# City not found. Skipping...
# Processing Record 39 of Set 10 | namie
# Processing Record 40 of Set 10 | ejura
# Processing Record 41 of Set 10 | pangody
# Processing Record 42 of Set 10 | cayenne
# Processing Record 43 of Set 10 | babushkin
# Processing Record 44 of Set 10 | lalmohan
# Processing Record 45 of Set 10 | cherskiy
# Processing Record 46 of Set 10 | trelleborg
# Processing Record 47 of Set 10 | talcher
# Processing Record 48 of Set 10 | eustis
# Processing Record 49 of Set 10 | mayumba
# Processing Record 50 of Set 10 | povenets
# Processing Record 1 of Set 11 | faratsiho
# Processing Record 2 of Set 11 | bilibino
# Processing Record 3 of Set 11 | baijiantan
# Processing Record 4 of Set 11 | olafsvik
# Processing Record 5 of Set 11 | great yarmouth
# Processing Record 6 of Set 11 | coruripe
# Processing Record 7 of Set 11 | santa luzia
# Processing Record 8 of Set 11 | zavallya
# Processing Record 9 of Set 11 | stryn
# Processing Record 10 of Set 11 | manggar
# Processing Record 11 of Set 11 | nueva loja
# Processing Record 12 of Set 11 | zaysan
# Processing Record 13 of Set 11 | opotiki
# Processing Record 14 of Set 11 | chernyshevskiy
# Processing Record 15 of Set 11 | codrington
# Processing Record 16 of Set 11 | tommot
# Processing Record 17 of Set 11 | fuzhou
# Processing Record 18 of Set 11 | minudasht
# Processing Record 19 of Set 11 | mareeba
# Processing Record 20 of Set 11 | oranjemund
# Processing Record 21 of Set 11 | svetlaya
# Processing Record 22 of Set 11 | gushikawa
# Processing Record 23 of Set 11 | muroto
# Processing Record 24 of Set 11 | palmer
# Processing Record 25 of Set 11 | batagay
# Processing Record 26 of Set 11 | vestbygda
# City not found. Skipping...
# Processing Record 27 of Set 11 | viedma
# Processing Record 28 of Set 11 | meadow lake
# Processing Record 29 of Set 11 | tautira
# Processing Record 30 of Set 11 | inhambane
# Processing Record 31 of Set 11 | mount gambier
# Processing Record 32 of Set 11 | lososina
# Processing Record 33 of Set 11 | nantucket
# Processing Record 34 of Set 11 | lucea
# Processing Record 35 of Set 11 | kedougou
# Processing Record 36 of Set 11 | shestakovo
# Processing Record 37 of Set 11 | meyungs
# City not found. Skipping...
# Processing Record 38 of Set 11 | te anau
# Processing Record 39 of Set 11 | tamandare
# Processing Record 40 of Set 11 | dolinsk
# Processing Record 41 of Set 11 | kisangani
# Processing Record 42 of Set 11 | bolitoc
# Processing Record 43 of Set 11 | eyl
# Processing Record 44 of Set 11 | prince rupert
# Processing Record 45 of Set 11 | fillmore
# Processing Record 46 of Set 11 | monte alegre
# Processing Record 47 of Set 11 | shenandoah
# Processing Record 48 of Set 11 | key west
# Processing Record 49 of Set 11 | bocaranga
# City not found. Skipping...
# Processing Record 50 of Set 11 | bathsheba
# Processing Record 1 of Set 12 | sturgis
# Processing Record 2 of Set 12 | khandbari
# Processing Record 3 of Set 12 | batemans bay
# Processing Record 4 of Set 12 | nanma
# Processing Record 5 of Set 12 | cayhagan
# Processing Record 6 of Set 12 | half moon bay
# Processing Record 7 of Set 12 | torres novas
# Processing Record 8 of Set 12 | ngukurr
# City not found. Skipping...
# Processing Record 9 of Set 12 | srednekolymsk
# Processing Record 10 of Set 12 | veere
# Processing Record 11 of Set 12 | xining
# Processing Record 12 of Set 12 | la ronge
# Processing Record 13 of Set 12 | lompoc
# Processing Record 14 of Set 12 | praya
# Processing Record 15 of Set 12 | qui nhon
# Processing Record 16 of Set 12 | nazarovo
# Processing Record 17 of Set 12 | whitianga
# Processing Record 18 of Set 12 | changji
# Processing Record 19 of Set 12 | haapsalu
# Processing Record 20 of Set 12 | khonuu
# City not found. Skipping...
# Processing Record 21 of Set 12 | kudahuvadhoo
# Processing Record 22 of Set 12 | camacha
# Processing Record 23 of Set 12 | vanavara
# Processing Record 24 of Set 12 | pirojpur
# Processing Record 25 of Set 12 | yungay
# Processing Record 26 of Set 12 | ginir
# Processing Record 27 of Set 12 | nouadhibou
# Processing Record 28 of Set 12 | tubruq
# City not found. Skipping...
# Processing Record 29 of Set 12 | itarema
# Processing Record 30 of Set 12 | laje
# Processing Record 31 of Set 12 | kulhudhuffushi
# Processing Record 32 of Set 12 | tukrah
# Processing Record 33 of Set 12 | nioro
# Processing Record 34 of Set 12 | tanshui
# City not found. Skipping...
# Processing Record 35 of Set 12 | cajetina
# Processing Record 36 of Set 12 | padang
# Processing Record 37 of Set 12 | devarkonda
# Processing Record 38 of Set 12 | ust-kuyga
# Processing Record 39 of Set 12 | praxedis guerrero
# Processing Record 40 of Set 12 | navahrudak
# Processing Record 41 of Set 12 | albino
# Processing Record 42 of Set 12 | nuuk
# Processing Record 43 of Set 12 | mvuma
# Processing Record 44 of Set 12 | kizukuri
# Processing Record 45 of Set 12 | flinders
# Processing Record 46 of Set 12 | sistranda
# Processing Record 47 of Set 12 | lerwick
# Processing Record 48 of Set 12 | clarksdale
# Processing Record 49 of Set 12 | kedrovyy
# Processing Record 50 of Set 12 | akdagmadeni
# Processing Record 1 of Set 13 | anse-bertrand
# Processing Record 2 of Set 13 | la sarre
# Processing Record 3 of Set 13 | okha
# Processing Record 4 of Set 13 | zhezkazgan
# Processing Record 5 of Set 13 | lukovetskiy
# Processing Record 6 of Set 13 | tezu
# Processing Record 7 of Set 13 | manta
# Processing Record 8 of Set 13 | yeniseysk
# Processing Record 9 of Set 13 | vaasa
# Processing Record 10 of Set 13 | kanye
# Processing Record 11 of Set 13 | chagda
# City not found. Skipping...
# Processing Record 12 of Set 13 | port hedland
# Processing Record 13 of Set 13 | balabac
# Processing Record 14 of Set 13 | gat
# Processing Record 15 of Set 13 | poum
# Processing Record 16 of Set 13 | wynyard
# Processing Record 17 of Set 13 | jharsuguda
# Processing Record 18 of Set 13 | nyurba
# Processing Record 19 of Set 13 | bulawayo
# Processing Record 20 of Set 13 | nykobing
# City not found. Skipping...
# Processing Record 21 of Set 13 | coquimbo
# Processing Record 22 of Set 13 | portales
# Processing Record 23 of Set 13 | gbarnga
# Processing Record 24 of Set 13 | emerald
# Processing Record 25 of Set 13 | tongchuan
# Processing Record 26 of Set 13 | de-kastri
# Processing Record 27 of Set 13 | fagersta
# Processing Record 28 of Set 13 | guapo
# Processing Record 29 of Set 13 | mana
# Processing Record 30 of Set 13 | ondorhaan
# City not found. Skipping...
# Processing Record 31 of Set 13 | shagonar
# Processing Record 32 of Set 13 | elko
# Processing Record 33 of Set 13 | villarrobledo
# Processing Record 34 of Set 13 | bajos de haina
# Processing Record 35 of Set 13 | mackay
# Processing Record 36 of Set 13 | oistins
# Processing Record 37 of Set 13 | maragogi
# Processing Record 38 of Set 13 | taltal
# Processing Record 39 of Set 13 | lixourion
# Processing Record 40 of Set 13 | urazovo
# Processing Record 41 of Set 13 | saint anthony
# Processing Record 42 of Set 13 | haysville
# Processing Record 43 of Set 13 | ngunguru
# Processing Record 44 of Set 13 | umzimvubu
# City not found. Skipping...
# Processing Record 45 of Set 13 | otuzco
# Processing Record 46 of Set 13 | vila velha
# Processing Record 47 of Set 13 | turayf
# Processing Record 48 of Set 13 | zemio
# Processing Record 49 of Set 13 | sur
# Processing Record 50 of Set 13 | fairbanks
# Processing Record 1 of Set 14 | pundaguitan
# Processing Record 2 of Set 14 | college
# Processing Record 3 of Set 14 | cidreira
# Processing Record 4 of Set 14 | awjilah
# Processing Record 5 of Set 14 | channel-port aux basques
# Processing Record 6 of Set 14 | tselina
# Processing Record 7 of Set 14 | wewak
# Processing Record 8 of Set 14 | alta floresta
# Processing Record 9 of Set 14 | port-cartier
# Processing Record 10 of Set 14 | beringovskiy
# Processing Record 11 of Set 14 | suez
# Processing Record 12 of Set 14 | oksfjord
# Processing Record 13 of Set 14 | havelock
# Processing Record 14 of Set 14 | bereda
# Processing Record 15 of Set 14 | mabaruma
# Processing Record 16 of Set 14 | mapiripan
# Processing Record 17 of Set 14 | dawlatabad
# Processing Record 18 of Set 14 | tambo
# Processing Record 19 of Set 14 | la asuncion
# Processing Record 20 of Set 14 | colinas
# Processing Record 21 of Set 14 | maniitsoq
# Processing Record 22 of Set 14 | zwedru
# Processing Record 23 of Set 14 | narsaq
# Processing Record 24 of Set 14 | moerewa
# Processing Record 25 of Set 14 | amahai
# Processing Record 26 of Set 14 | koungou
# Processing Record 27 of Set 14 | yerofey pavlovich
# Processing Record 28 of Set 14 | bochov
# Processing Record 29 of Set 14 | umm durman
# City not found. Skipping...
# Processing Record 30 of Set 14 | mollendo
# Processing Record 31 of Set 14 | sembe
# Processing Record 32 of Set 14 | bowen
# Processing Record 33 of Set 14 | arawa
# Processing Record 34 of Set 14 | murgab
# Processing Record 35 of Set 14 | churapcha
# Processing Record 36 of Set 14 | sar-e pul
# Processing Record 37 of Set 14 | urengoy
# Processing Record 38 of Set 14 | zhengjiatun
# Processing Record 39 of Set 14 | umba
# Processing Record 40 of Set 14 | ondal
# City not found. Skipping...
# Processing Record 41 of Set 14 | chulym
# Processing Record 42 of Set 14 | roebourne
# Processing Record 43 of Set 14 | soldotna
# Processing Record 44 of Set 14 | davila
# Processing Record 45 of Set 14 | okhotsk
# Processing Record 46 of Set 14 | hailin
# Processing Record 47 of Set 14 | bealanana
# Processing Record 48 of Set 14 | tonantins
# Processing Record 49 of Set 14 | keratea
# Processing Record 50 of Set 14 | den helder
# Processing Record 1 of Set 15 | acapulco
# Processing Record 2 of Set 15 | chiman
# Processing Record 3 of Set 15 | nacunday
# City not found. Skipping...
# Processing Record 4 of Set 15 | saint-louis
# Processing Record 5 of Set 15 | phan thiet
# Processing Record 6 of Set 15 | shenjiamen
# Processing Record 7 of Set 15 | taitung
# Processing Record 8 of Set 15 | evensk
# Processing Record 9 of Set 15 | tarumovka
# Processing Record 10 of Set 15 | le havre
# Processing Record 11 of Set 15 | belaya gora
# Processing Record 12 of Set 15 | georgiyevka
# Processing Record 13 of Set 15 | cam ranh
# Processing Record 14 of Set 15 | santa rosa
# Processing Record 15 of Set 15 | candawaga
# City not found. Skipping...
# Processing Record 16 of Set 15 | ilhabela
# Processing Record 17 of Set 15 | roxana
# Processing Record 18 of Set 15 | ishinomaki
# Processing Record 19 of Set 15 | zhukovo
# Processing Record 20 of Set 15 | turukhansk
# Processing Record 21 of Set 15 | sabang
# Processing Record 22 of Set 15 | penon blanco
# Processing Record 23 of Set 15 | qaqortoq
# Processing Record 24 of Set 15 | puerto madero
# Processing Record 25 of Set 15 | kamaishi
# Processing Record 26 of Set 15 | kosa
# Processing Record 27 of Set 15 | tiarei
# Processing Record 28 of Set 15 | general roca
# Processing Record 29 of Set 15 | gulbene
# Processing Record 30 of Set 15 | yenagoa
# Processing Record 31 of Set 15 | menongue
# Processing Record 32 of Set 15 | piacabucu
# Processing Record 33 of Set 15 | zhanaozen
# Processing Record 34 of Set 15 | san carlos de bariloche
# Processing Record 35 of Set 15 | odweyne
# Processing Record 36 of Set 15 | mumford
# Processing Record 37 of Set 15 | jurbarkas
# Processing Record 38 of Set 15 | tessalit
# Processing Record 39 of Set 15 | zonguldak
# Processing Record 40 of Set 15 | jaisalmer
# Processing Record 41 of Set 15 | shache
# Processing Record 42 of Set 15 | ishigaki
# Processing Record 43 of Set 15 | buala
# Processing Record 44 of Set 15 | kerteh
# City not found. Skipping...
# Processing Record 45 of Set 15 | samalaeulu
# City not found. Skipping...
# Processing Record 46 of Set 15 | chiredzi
# Processing Record 47 of Set 15 | rosetta
# Processing Record 48 of Set 15 | pierre
# Processing Record 49 of Set 15 | bima
# Processing Record 50 of Set 15 | lianran
# Processing Record 1 of Set 16 | ferme-neuve
# Processing Record 2 of Set 16 | malanje
# Processing Record 3 of Set 16 | bindura
# Processing Record 4 of Set 16 | broadstairs
# Processing Record 5 of Set 16 | ulaanbaatar
# Processing Record 6 of Set 16 | abu samrah
# Processing Record 7 of Set 16 | ayan
# Processing Record 8 of Set 16 | siddapur
# Processing Record 9 of Set 16 | gulshat
# City not found. Skipping...
# Processing Record 10 of Set 16 | salinopolis
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# 700

# %%
challenge_city_data_df = pd.DataFrame(city_data)
challenge_city_data_df.to_csv(path_or_buf='Weather_Database/WeatherPy_Database.csv', index_label='City_ID')
